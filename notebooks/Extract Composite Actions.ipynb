# %% [markdown]
# This notebook aims to quantify the use of composite Actions. To do so, we look for the content of `action.yml` file for the Actions we have in our dataset, and see which ones are composite (i.e., `using: composite` in the `runs` section).

# %%
import pandas as pd
import requests

import ruamel.yaml as yaml
import multiprocessing

from tqdm import tqdm

# %%
df_actions = (
    pd.read_csv('../data/releases.csv.gz')
    .sort_values('date')
    .drop_duplicates(['owner', 'repo'], keep='last')
)

# %%
df_actions.head()
# Out:
#             owner                     repo release                       date
# 19698     actions                   heroku   1.0.0  2018-12-17 23:49:29+00:00
# 24863  cadwallion  publish-rubygems-action  v1.0.0  2019-01-17 18:17:13+00:00
# 11526   andymckay       pycodestyle-action   0.1.3  2019-01-17 19:21:00+00:00
# 21568    gimenete            eslint-action     1.0  2019-01-31 22:12:22+00:00
# 24889    gimenete           rubocop-action     1.0  2019-02-01 06:03:25+00:00

# %%
def extract_using(content):
    parser = yaml.YAML()
    parser.allow_duplicate_keys = True
    
    try:
        action = parser.load(content)
    except Exception:  # Don't blame me for this!
        return None
    
    if action is None: 
        return None
    
    using = action.get('runs', {}).get('using', None)
    return using

# %%
def job(owner, repo, release):
    r = requests.get('https://raw.githubusercontent.com/{}/{}/{}/action.yml'.format(owner, repo, release))
    if r.status_code != 200:
        return None
    return extract_using(r.content)

# %%
output = []

for row in tqdm(df_actions.itertuples(), total=len(df_actions)):
    output.append((
        row.owner, 
        row.repo,
        job(row.owner, row.repo, row.release)
    ))
# Out:
# 100%|███████████████████████████████████████| 2812/2812 [12:43<00:00,  3.68it/s]

# %%
df = pd.DataFrame(output, columns=['owner', 'repo', 'using'])

# %%
(
    df
    .groupby('using', dropna=False)
    .count()
    .assign(prop=lambda d: d.owner / d.owner.sum())
    .sort_values('prop', ascending=False)
)
# Out:
#            owner  repo      prop
# using
# node12      1237  1237  0.439900
# docker       727   727  0.258535
# node16       360   360  0.128023
# composite    297   297  0.105619
# NaN          191   191  0.067923

# %%
(
    df
    [lambda d: d.using == 'composite']
    .assign(action=lambda d: d.owner + '/' + d.repo)
    .action
    .to_list()
)
# Out:
# ['browniebroke/read-nvmrc-action',
#  'jossef/action-semantic-releaser',
#  'tomhjp/gh-action-jira-search',
#  'isbang/setup-awscli',
#  'get-woke/woke-action',
#  'get-woke/woke-action-reviewdog',
#  'p3terx/ssh2actions',
#  'rdarida/simple-github-pages-deploy-action',
#  'r0wi/nextcloud-appstore-push-action',
#  'sdkman/sdkman-action',
#  'ktibow/ha-blueprint',
#  'tomhjp/gh-action-jira-create',
#  'tomhjp/gh-action-jira-comment',
#  'mstachniuk/ci-skip',
#  'egor-tensin/vs-shell',
#  'myci-actions/export-env-var',
#  'myci-actions/export-env-var-powershell',
#  'dawidd6/action-publish-gem',
#  'davidlienhard/php-simple-lint',
#  'anton-latukha/test-haskell-nixpkgs-integration-action',
#  'curoky/cleanup-disk-action',
#  'crossplane-contrib/xpkg-action',
#  'syndesisio/backport-action',
#  'ryankurte/action-apt',
#  'ory/build-buf-action',
#  'nbadal/action-ktlint-setup',
#  'browniebroke/pre-commit-autoupdate-action',
#  'airvzxf/cache-anything-new-action',
#  'egor-tensin/setup-cygwin',
#  'egor-tensin/setup-mingw',
#  'egor-tensin/setup-gcc',
#  'egor-tensin/setup-clang',
#  'deadsnakes/action',
#  'fish-actions/install-fish',
#  'zencargo/github-action-go-mod-tidy',
#  'ymyzk/run-tox-gh-actions',
#  'amadevus/pwsh-script',
#  'tristanbarlow/setup-elasticbeanstalk-cli',
#  'doyensec/electronegativity-action',
#  'andreacomo/maven-gav-extractor',
#  'ktomk/run-travis-yml',
#  'miragenet/setup-docfx',
#  'tj-actions/pg-restore',
#  'xarray-contrib/ci-trigger',
#  'ttuegel/upload-release.nix',
#  'reviewdog/action-setup',
#  'fabriciomurta/ensure-nuget-source',
#  'wangchucheng/git-repo-sync',
#  'mattes/gce-cloudsql-proxy-action',
#  'egor-tensin/build-boost',
#  'dawidd6/action-homebrew-bump-formula',
#  'myci-actions/publish-nuget',
#  'splunk/biased-lang-linter',
#  'arduino/cpp-test-action',
#  'per1234/install-arduino-ci-script-action',
#  'embano1/wip',
#  'sormuras/download-jdk',
#  'imciner2/run-lcov',
#  'malept/github-action-dependabolt',
#  'php-actions/phpunit',
#  'php-actions/composer',
#  'php-actions/phpstan',
#  'sublimetext/syntax-test-action',
#  'alanhg/repo-star-count-action',
#  'maidsafe/pr_size_checker',
#  'pierotofy/set-swap-space',
#  'rive-app/github-actions-submodule-check',
#  'cardanosolutions/gh-action-cardano-node-ogmios-docker-sync',
#  'julia-actions/julia-buildpkg',
#  'erickzanardo/flutter-gh-pages',
#  'myci-actions/add-pacman-repo',
#  'lucacome/docker-image-update-checker',
#  'russorat/influxdb-action',
#  'influxdata/influxdb-action',
#  'britannio/action-install-flutter',
#  'danielmundi/upload-packagecloud',
#  'synergy-au/download-workflow-artifacts-action',
#  'actions-automation/pull-request-responsibility',
#  'myci-actions/add-deb-repo',
#  'dieghernan/cff-validator',
#  'tailscale/github-action',
#  'maxdesiatov/swift-windows-action',
#  'microsoft/install-databricks-cli',
#  'casperdcl/deploy-pypi',
#  'casperdcl/push-dir',
#  'particular/virus-scan-action',
#  'rlalik/setup-cpp-compiler',
#  'stackrox/kube-linter-action',
#  'rekgrpth/github-repository-dispatch-shell-action',
#  'ibiqlik/action-yamllint',
#  'dart-lang/setup-dart',
#  'testspace-com/setup-testspace',
#  'willabides/setup-go-faster',
#  'sourcegraph/lsif-rust-action',
#  'protocol/multiple-go-modules',
#  'potatoqualitee/azuright',
#  'mozgiii/install-ldid-action',
#  'ndeloof/install-compose-action',
#  'dropseed/changerelease',
#  'ludeeus/setup-homeassistant',
#  'dtinth/patch-generator-action',
#  'visiosto/replace-value',
#  're-actors/alls-green',
#  'protocol/cache-go-action',
#  'ipfs/start-ipfs-daemon-action',
#  'cpcloud/flake-update-action',
#  'macauley/action-homebrew-bump-cask',
#  'emulator-wtf/run-tests',
#  'ramsey/composer-install',
#  'rlespinasse/git-commit-data-action',
#  'abbbi/github-actions-tune',
#  'creyd/prettier_action',
#  'codacy/codacy-coverage-reporter-action',
#  'aio-libs/prepare-coverage',
#  'neuro-inc/prepare-coverage',
#  'aio-libs/upload-coverage',
#  'neuro-inc/upload-coverage',
#  'nickofthyme/checkout-node-setup',
#  'pyvista/setup-headless-display-action',
#  'codacy/git-version',
#  'hazelcast/github-jira-tool-action',
#  'abatilo/release-info-action',
#  'cschoel/release-notes-from-changelog',
#  'nature40/pimod',
#  'char0n/swagger-editor-validate',
#  'humbletim/setup-vulkan-sdk',
#  'jonasalfredsson/docker-on-tmpfs',
#  'ory/closed-reference-notifier',
#  'snok/install-poetry',
#  'humbletim/install-vulkan-sdk',
#  'reenignearcher/facebook-post-action',
#  'guillaumefalourd/clone-github-repo-action',
#  'getsentry/action-prepare-release',
#  'aaronfriel/action-configure-pagefile',
#  'rseng/zenodo-release',
#  'brechtm/setup-scoop',
#  'camunda-community-hub/community-action-maven-release',
#  'cygwin/cygwin-install-action',
#  'erzz/codeclimate-standalone',
#  'cytopia/shell-command-retry-action',
#  'akosbalasko/coffee-readme',
#  'shubhamtatvamasi/terraform-lint-action',
#  'nebularg/actions-luacheck',
#  'arduino/compile-sketches',
#  'jbergstroem/hadolint-gh-action',
#  'prisma/action-node-cache-dependencies',
#  'helm/chart-releaser-action',
#  'pr-annotators/mypy-pr-annotator',
#  'crazy-max/ghaction-dump-context',
#  'ethersphere/beeload-action',
#  'julia-actions/julia-docdeploy',
#  'thedoctor0/zip-release',
#  'linuxdeepin/action-cppcheck',
#  'usefulness/diffuse-action',
#  'rossjrw/pr-preview-action',
#  'elgohr/publish-docker-github-action',
#  'tlylt/install-graphviz',
#  'myci-actions/checkout',
#  'elgohr/github-release-action',
#  'openzim/docker-publish-action',
#  'reviewdog/action-eslint',
#  'reviewdog/action-suggester',
#  'reviewdog/action-tflint',
#  'reviewdog/action-stylelint',
#  'mgrachev/action-hadolint',
#  'reviewdog/action-hadolint',
#  'reviewdog/action-shellcheck',
#  'reviewdog/action-staticcheck',
#  'reviewdog/action-shfmt',
#  'dotenv-linter/action-dotenv-linter',
#  'tsuyoshicho/action-textlint',
#  'duckdb/duckdb-wasm-ci-env',
#  'joelanford/go-apidiff',
#  'steffo99/actions-semver',
#  'reviewdog/action-remark-lint',
#  'reviewdog/action-flake8',
#  'tencentcloudbase/cloudbase-action',
#  'honeybunch/setup-mingw',
#  'epmatt/reviewdog-action-prettier',
#  'dciborow/action-pylint',
#  'jandelgado/gcov2lcov-action',
#  'per1234/artistic-style-action',
#  'truebrain/actions-flake8',
#  'espressif/esp-idf-ci-action',
#  'gitopia/gitopia-mirror-action',
#  'bison-packages/install-bison',
#  'jamescurtin/isort-action',
#  'isort/isort-action',
#  'potatoqualitee/mssqlsuite',
#  'ethersphere/update-supported-bee-action',
#  'leleliu008/github-actions-vagrant',
#  'esphome/build-action',
#  'reviewdog/action-rubocop',
#  'dansiegel/publish-nuget',
#  'pre-commit/action',
#  'pguyot/arm-runner-action',
#  'marian-code/python-lint-annotate',
#  'whisperity/codechecker-analysis-action',
#  'bdougie/take-action',
#  'codacy/codacy-analysis-cli-action',
#  'jreleaser/release-action',
#  'chetan/invalidate-cloudfront-action',
#  'mario-campos/emulate',
#  'petronny/git-config-user',
#  'jonasalfredsson/checkout-qemu-buildx',
#  'jlumbroso/free-disk-space',
#  'easimon/maximize-build-space',
#  'metamask/action-create-release-pr',
#  'dtolnay/install',
#  'uibcdf/action-sphinx-docs-to-gh-pages',
#  'ikalnytskyi/action-setup-postgres',
#  'lewagon/wait-on-check-action',
#  'erzz/dockle-action',
#  'metamask/action-npm-publish',
#  'chevdor/srtool-actions',
#  'metamask/action-publish-release',
#  'flank/flank',
#  'retypeapp/action-build',
#  'dtolnay/rust-toolchain',
#  'clementtsang/cargo-action',
#  'kaste/upgrade-messages-test-action',
#  'dprint/check',
#  'mobsf/mobsfscan',
#  'kevincobain2000/action-gobrew',
#  'actions-rust-lang/rustfmt',
#  'check-spelling/check-spelling',
#  'trailofbits/gh-action-pip-audit',
#  'imjasonh/setup-crane',
#  'vapier/coverity-scan-action',
#  'lycheeverse/lychee-action',
#  'pdm-project/update-deps-action',
#  'aio-libs/create-release',
#  'sclorg/build-and-push-action',
#  'cert-polska/lint-python-action',
#  'mercymeilya/last-workflow-status',
#  'julia-actions/julia-runtest',
#  'ahmadnassri/action-metadata',
#  'bewuethr/shellcheck-action',
#  'oracle-actions/setup-java',
#  'pybuilder/build',
#  'pavelzw/pytest-action',
#  'helm/chart-testing-action',
#  'turtlebrowser/get-conan',
#  'usefulness/dependency-tree-diff-action',
#  'actions-rust-lang/audit',
#  'untitaker/hyperlink',
#  '10up/action-wordpress-plugin-deploy',
#  '10up/action-wordpress-plugin-asset-update',
#  'jpetrucciani/mypy-check',
#  's4u/setup-maven-action',
#  'devlooped/actions-sponsor',
#  'bwoodsend/setup-winlibs-action',
#  'jirutka/setup-alpine',
#  'jupyterhub/action-k3s-helm',
#  'arminjo/arduino-test-compile',
#  'tsuyoshicho/action-mypy',
#  'abatilo/actions-poetry',
#  'ewels/rich-codex',
#  'tj-actions/verify-changed-files',
#  'raybellwaves/nbdime-git-diff',
#  'schemathesis/action',
#  'tj-actions/branch-names',
#  'jurplel/install-qt-action',
#  'mpi4py/setup-mpi',
#  'ipfs/download-ipfs-distribution-action',
#  'dineshsonachalam/markdown-autodocs',
#  'art049/mongodb-cluster-action',
#  'ok-nick/setup-aftman',
#  'sualeh/prepare-maven-build',
#  'psf/black',
#  'awalsh128/cache-apt-pkgs-action',
#  'actions/upload-pages-artifact',
#  'artiomtr/jest-coverage-report-action',
#  'gi0baro/setup-poetry-bin',
#  'imjasonh/setup-ko',
#  'leonsteinhaeuser/project-beta-automations',
#  'home-assistant/builder',
#  'nrwl/nx-set-shas',
#  'sclorg/testing-farm-as-github-action',
#  'lowlighter/metrics',
#  'deryeger/yarn-setup-action',
#  'nearform/optic-release-automation-action',
#  'nearform/optic-release-automation',
#  'sigstore/cosign-installer',
#  'akaihola/darker',
#  'jidicula/clang-format-action',
#  'sturdy-dev/codeball-action',
#  'potatoqualitee/psmodulecache',
#  'determinatesystems/update-flake-lock',
#  'actions-rust-lang/setup-rust-toolchain',
#  'subosito/flutter-action',
#  'getsentry/action-app-sdk-overhead-metrics',
#  'pypa/cibuildwheel',
#  'joerick/cibuildwheel',
#  'cpp-linter/cpp-linter-action',
#  'shenxianpeng/cpp-linter-action',
#  'tj-actions/changed-files']
