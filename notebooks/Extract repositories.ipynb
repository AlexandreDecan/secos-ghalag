# %% [markdown]
# See `README` file for more information about the process performed by this notebook.

# %%
import pandas as pd
import requests
from tqdm import tqdm 

import subprocess
import shutil
from multiprocessing import Pool
from pathlib import Path
from functools import partial

# %%
# Path to clone repositories
WORKING = Path('/data/ghactions')
WORKERS = 40

# %%
repositories = (
    pd.read_csv('../data-raw/repositories.csv')
    # Exclude very large repositories, for disk space purposes
    .query('size <= 500 * 1024')
    [['name', 'defaultBranch']]
    .sort_values('name')
    .values
    .tolist()
)

# %%
print(f'There are {len(repositories)} repositories.')
# Out:
# There are 62673 repositories.

# %% [markdown]
# Let's define a function that will do most of the job for a given repository and its default branch. Inline comments explain the process.

# %%
def download_workflows(base_path: Path, repo: str, branch: str, skip_existing=False, timeout=None):
    """
    Download the GitHub workflow files for given repository. 
    
    :param base_path: target path for downloading the repository. 
    :param repo: name of the repository on GitHub. 
    :param branch: name of the branch to consider.
    :param timeout: timeout for individual command (in seconds).
    """
    # Create repository folder
    path = base_path / repo.replace('/', '---')
    try:
        path.mkdir(parents=True)
    except FileExistsError:
        if not skip_existing:
            raise
       
    # Check if given repository has a .github/workflow folder
    url = f'https://github.com/{repo}/tree/{branch}/.github/workflows'
    r = requests.head(url)
    if r.status_code == 404:
        # Remove folder
        shutil.rmtree(path)
        return
    
    # Quick helper
    cmd = partial(subprocess.run, cwd=path, capture_output=True, timeout=timeout)
    
    # Initialize git repository
    out = cmd(['git', 'init'])
    
    # Configure git repository
    out = cmd(['git', 'remote', 'add', 'origin', 'https://github.com/' + repo])
    out = cmd(['git', 'config', 'core.sparsecheckout', 'true'])
    (path / '.git/info/sparse-checkout').write_text('.github/workflows\n')
    
    # Pull default branch
    try:
        out = cmd(['git', 'pull', 'origin', branch])
        out.check_returncode()
    except (subprocess.CalledProcessError, subprocess.TimeoutExpired):
        # Remove folder
        shutil.rmtree(path)
        raise

# %% [markdown]
# Let's define a thin wrapper to handle errors.

# %%
def job(repository):
    repo, branch = repository
    try:
        download_workflows(WORKING, repo, branch, skip_existing=True, timeout=None)
        return repo, branch
    except Exception as e: 
        return repo, branch, e

# %%
output = []
inputs = repositories[:]

with Pool(processes=WORKERS) as pool:
    jobs = pool.imap_unordered(job, inputs)
    for r in tqdm(jobs, total=len(inputs)):
        output.append(r)
# Out:
#   1%|▎                                   | 600/62673 [08:18<15:47:28,  1.09it/s]

# %%
failures = [x for x in output if len(x) == 3]
print(f'There are {len(failures)} failing repositories out of {len(output)}.')
print('\n'.join(map(str, failures)))
# Out:
# There are 173 failing repositories out of 62673.
# ('0zz4r/bashflix', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('aeb-labs/cruddl', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('agile-geoscience/striplog', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('agile-geoscience/bruges', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('aicoe/prometheus-api-client-python', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('akabekobeko/npm-icon-gen', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('alephjs/esm.sh', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('algolia/docsearch', 'next', CalledProcessError(1, ['git', 'pull', 'origin', 'next'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante next\n'))
# ('altibase/altibase', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('aomediacodec/svt-av1', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('automattic/jetpack', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('aws-amplify/community', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('aws/aws-cdk', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('ballantyne/weibo', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('blacksphere/blackmagic', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('blocknative/onboard', 'develop', CalledProcessError(1, ['git', 'pull', 'origin', 'develop'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante develop\n'))
# ('boostchicken-dev/udm-utilities', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('botuniverse/onebot', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('brillout/vite-plugin-ssr', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('capacitor-community/capacitor-googlemaps-native', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('checkr/flagr', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('chrisj42/minicraft-plus-revived', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('clickhouse/clickhouse-go', 'v2', CalledProcessError(1, ['git', 'pull', 'origin', 'v2'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante v2\n'))
# ('cloud-bulldozer/kraken', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('cloud-bulldozer/krkn', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('clue/reactphp-socks', 'main', CalledProcessError(1, ['git', 'pull', 'origin', 'main'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante main\n'))
# ('codereport/talks', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('cookiecutter/cookiecutter', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('coregreenberet/homematicip-rest-api', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('coreyginnivan/system-uicons', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('coreyginnivan/whocanuse', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('countr/countr', 'djs-13', CalledProcessError(1, ['git', 'pull', 'origin', 'djs-13'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante djs-13\n'))
# ('crowi/crowi', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('danforthcenter/plantcv', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('danvick/flutter_form_builder', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('darkreader/darkreader', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('datarhei/restreamer', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('davidsbond/terraform-provider-tailscale', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('discord/discord-api-docs', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('donbeave/graphql-java-datetime', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('dundunnp/hamibot-auto_xuexiqiangguo', 'main', CalledProcessError(1, ['git', 'pull', 'origin', 'main'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante main\n'))
# ('dvargas92495/roam-js-extensions', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('edrosten/libcvd', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('elrumordelaluz/reactour', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('emberjs/ember-inspector', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('erikw/restic-systemd-automatic-backup', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('esm-dev/esm.sh', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('exhibitionist-digital/ultra', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('ferreusveritas/dynamictrees', '1.12.2', CalledProcessError(1, ['git', 'pull', 'origin', '1.12.2'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante 1.12.2\n'))
# ('filecoin-project/filecoin-docs', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('friendsofsymfony/foshttpcache', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('friendsofsymfony/foshttpcachebundle', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('gabe-h/gemini', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('gate-computer/wag', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('gd-programming/gddocs', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('github/opensourcefriday', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('goauthentik/authentik', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('google/shaka-player-embedded', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('google/shaka-player', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('google/shaka-streamer', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('grantmcconnaughey/django-avatar', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('gruntwork-io/kubergrunt', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('gsi-cs-co/chart-fx', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('hakancelik96/unimport', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('hfp/libxsmm', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('honojs/hono', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('hypermodules/gh-release', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('i3/i3status', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('icepy/icepy.me', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('idevision/enhanced-discord.py', '2.0', CalledProcessError(1, ['git', 'pull', 'origin', '2.0'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante 2.0\n'))
# ('jails-org/jails', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('jeffail/benthos', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('joeattardi/emoji-button', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('jonaskello/eslint-plugin-functional', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('jupyter/enterprise_gateway', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('jupyter/notebook', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('kiberneticworm/kotlin-algorithms-and-design-patterns', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('kolide/launcher', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('kubeapps/kubeapps', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('kylebrowning/apnswift', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('laststance/create-react-app-typescript-todo-example-2021', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('laststance/create-react-app-typescript-todo-example-2022', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('laststance/react-app-typescript-todo-example-2022', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lawl/noisetorch', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('loft-sh/devspace', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lucaburgio/iconoir', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('lwjglgamedev/lwjglbook', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('m0rf30/android-udev-rules', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mackorone/mms', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mdbootstrap/perfect-scrollbar', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mengzonefire/twitter-media-downloader', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('michaelklishin/tls-gen', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('microsoft/dowhy', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('microsoft/fluentui-react-native', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('microsoft/hcsshim', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('microsoft/xaml-controls-gallery', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('miguelripoll23/homebridge-securitysystem', 'stable', CalledProcessError(1, ['git', 'pull', 'origin', 'stable'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante stable\n'))
# ('miodec/monkeytype', 'dev', CalledProcessError(1, ['git', 'pull', 'origin', 'dev'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante dev\n'))
# ('mitsuhiko/redis-rs', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('mperham/connection_pool', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('myint/rstcheck', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('naiquevin/pipdeptree', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('nihlus/remora.discord', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('nmattia/homies', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('notifirehq/notifire', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('nwutils/nw-builder', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('oauth-xx/oauth-ruby', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('oauth-xx/oauth2', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('openflutter/flutter_image_compress', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('opszero/nixtune', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('optimistdigital/nova-menu-builder', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('optimistdigital/nova-multiselect-field', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('optimistdigital/nova-page-manager', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('optimistdigital/nova-settings', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('optimistdigital/nova-sortable', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('optimistdigital/nova-translatable', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('outl1ne/nova-sortable', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('phpstan/phpdoc-parser', '1.7.x', CalledProcessError(1, ['git', 'pull', 'origin', '1.7.x'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante 1.7.x\n'))
# ('pittcsc/summer2022-internships', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pittcsc/summer2023-internships', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('pixari/vue-i18n-extract', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('prefecthq/prefect', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('python-poetry/cleo', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('rdflib/rdflib', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('react-native-mapbox-gl/maps', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('reactive-resume/reactive-resume', 'develop', CalledProcessError(1, ['git', 'pull', 'origin', 'develop'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante develop\n'))
# ('realm/swiftlint', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('reclosedev/requests-cache', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('regen-network/regen-ledger', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('reiryuki/dolby-atmos-zte-a2019-pro-magisk-module', 'main', CalledProcessError(1, ['git', 'pull', 'origin', 'main'], b'', b"remote: Repository unavailable due to DMCA takedown.\nremote: See the takedown notice for more details:\nremote:   https://github.com/github/dmca/blob/master/2022/08/2022-08-23-dolby.md.\nfatal: impossible d'acc\xc3\xa9der \xc3\xa0 'https://github.com/reiryuki/dolby-atmos-zte-a2019-pro-magisk-module/'\xc2\xa0: The requested URL returned error: 403\n"))
# ('riflowth/skinsystem', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('roland09/prefabpainter', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('rythe-interactive/legion-engine', 'develop-2021.1', CalledProcessError(1, ['git', 'pull', 'origin', 'develop-2021.1'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante develop-2021.1\n'))
# ('samuelcolvin/pydantic', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('samuelcolvin/watchgod', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('sdispater/cleo', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('sentsin/layui', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('shuding/nextra', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('socketry/timers', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('sonatype/docker-nexus3', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('sonatype/nexus-public', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('spicywebau/craft-neo', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('spring-petclinic/spring-petclinic-graphql', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('standardnotes/web', 'develop', CalledProcessError(1, ['git', 'pull', 'origin', 'develop'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante develop\n'))
# ('strapi/strapi', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('substra/substra', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('superelastix/elastix', 'develop', CalledProcessError(1, ['git', 'pull', 'origin', 'develop'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante develop\n'))
# ('tafcoder/sleek-dashboard', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('tannerlinsley/react-query', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('tannerlinsley/react-virtual', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('theislab/squidpy', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('theskumar/python-dotenv', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('tobiasbg/tablepress', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('toml-lang/toml', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('tungs/timecut', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('tungs/timesnap', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('umbracle/go-web3', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('updated-classic/gta-reversed-modern', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('utmapp/utm', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vemel/mypy_boto3_builder', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('videlais/snowman', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vikejs/telefunc', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vuejs/vue-router-next', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('vuejs/vue-test-utils-next', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('wildbit/postmark-php', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('wildbit/postmark-rails', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('wildbit/postmark.js', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('wildfly/jandex', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('yusukebe/hono', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('yutkat/dotfiles', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('zamiell/hanabi-live', 'master', CalledProcessError(1, ['git', 'pull', 'origin', 'master'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante master\n'))
# ('zitadel/zitadel', 'v2-alpha', CalledProcessError(1, ['git', 'pull', 'origin', 'v2-alpha'], b'', b'fatal: impossible de trouver la r\xc3\xa9f\xc3\xa9rence distante v2-alpha\n'))
# ('zricethezav/gitleaks-action', 'v2', CalledProcessError(128, ['git', 'pull', 'origin', 'v2'], b'', b"Depuis https://github.com/zricethezav/gitleaks-action\n * tag               v2         -> FETCH_HEAD\nfatal: \xc3\xa9chec de update_ref pour la r\xc3\xa9f 'HEAD'\xc2\xa0: cannot update ref 'refs/heads/master': trying to write non-commit object ea73b80f2a0eb8814184f9a9c936a27247f9c151 to branch 'refs/heads/master'\n"))
